# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori

# %%
df = pd.read_csv('/content/drive/My Drive/RESEARCH/Sya/GPS Movement 2018 19 20/Scripts/pythonexample.csv')
df.columns
# Out:
# Index([' department1', ' department2', ' department3', ' department4',
#        ' department5', ' department6', ' department7', ' department8',
#        ' department9', ' grocery misc',
#        ...
#        ' department207', ' department208', ' department209', ' department210',
#        ' department211', ' department212', ' department213', ' department214',
#        ' department215', ' department216'],
#       dtype='object', length=216)

# %%
apriori(df, min_support=0.5, use_colnames=True)
# Out:
#      support                                           itemsets
# 0   0.736842                                  ( bread and cake)
# 1   0.736842                                    ( baking needs)
# 2   0.736842                               ( juice-sat-cord-ms)
# 3   0.684211                                        ( biscuits)
# 4   0.526316                               ( canned vegetables)
# 5   0.578947                               ( sauces-gravy-pkle)
# 6   0.526316                                    ( frozen foods)
# 7   0.578947                               ( party snack foods)
# 8   0.578947                                       ( margarine)
# 9   0.789474                                           ( frui1)
# 10  0.736842                                      ( vegetables)
# 11  0.631579                   ( baking needs,  bread and cake)
# 12  0.684211              ( juice-sat-cord-ms,  bread and cake)
# 13  0.631579                       ( bread and cake,  biscuits)
# ...
